# %% [markdown]
# # FIFA Data Summarize
# ### Include data :
# #### 1. Statistics data of each team
# #### 2. Events data of each game
# #### 3. Players data
# #### 4. Players value data
# #### 5. Competition history data

# %%
import pandas as pd 
import numpy as np 
import matplotlib as plt
# %matplotlib inline

# %% [markdown]
# # Read FIFA Data

# %% [markdown]
# ## Statistics data of each team

# %%
#目前47場比賽的資料
data = pd.read_csv("data/FIFA_statistics_data.csv")
data.head()
# Out:
#    attendance away_team_country              datetime    fifa_id  \
# 0       43319            Panama  2018-06-24T12:00:00Z  300331546
# 1       44190           Tunisia  2018-06-23T12:00:00Z  300331547
# 2       43866             Spain  2018-06-15T18:00:00Z  300331524
# 3       78011      Saudi Arabia  2018-06-14T15:00:00Z  300331503
# 4       33973           Morocco  2018-06-25T18:00:00Z  300340184
#
#   home_team_country  last_event_update_at  last_score_update_at  \
# 0           England  2018-06-24T13:53:42Z  2018-06-24T13:53:42Z
# 1           Belgium  2018-06-23T13:55:55Z  2018-06-23T13:55:55Z
# 2          Portugal  2018-06-21T02:36:18Z  2018-06-15T19:52:38Z
# 3            Russia  2018-06-21T02:36:44Z                   NaN
# 4             Spain  2018-06-25T19:56:26Z  2018-06-25T19:56:26Z
#
#                   location                                          officials  \
# 0  Nizhny Novgorod Stadium  ['Ghead GRISHA', 'Redouane ACHIK', 'Waleed AHM...
# ...

# %% [markdown]
# ## Events data of each game

# %%
event_data = pd.read_csv("data/Game_event_log.csv")
event_data.head()
# Out:
#   Away_team Home_team   ID          player time     type_of_event
# 0    Panama   England  521  Armando COOPER  10'       yellow-card
# 1    Panama   England  528   Fidel ESCOBAR  44'       yellow-card
# 2    Panama   England  527   Fidel ESCOBAR  45'       yellow-card
# 3    Panama   England  530    Anibal GODOY  62'  substitution-out
# 4    Panama   England  531   Ricardo AVILA  62'   substitution-in

# %% [markdown]
# ## Players data 1

# %%
playerdata = pd.read_csv("data/fifa2018playerlist.csv")
playerdata.head()
# Out:
#         Team  # Pos.   FIFA Popular Name  Birth Date  Shirt Name  \
# 0  Argentina  1   GK       GUZMAN Nahuel  10.02.1986      GUZM?N
# 1  Argentina  2   DF     MERCADO Gabriel  18.03.1987     MERCADO
# 2  Argentina  3   DF  TAGLIAFICO Nicolas  31.08.1992  TAGLIAFICO
# 3  Argentina  4   DF    ANSALDI Cristian  20.09.1986     ANSALDI
# 4  Argentina  5   MF        BIGLIA Lucas  30.01.1986      BIGLIA
#
#                 Club  Height  Weight
# 0  Tigres UANL (MEX)     192      90
# 1   Sevilla FC (ESP)     181      81
# 2     AFC Ajax (NED)     169      65
# 3    Torino FC (ITA)     181      73
# 4     AC Milan (ITA)     175      73

# %% [markdown]
# ## Players data 2 (include wage)

# %%
playerdata_wage = pd.read_csv("data/Players Value.csv")
playerdata_wage.head()
# Out:
# C:\Users\sasadm\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (23,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0               Name  Age  \
# 0           0  Cristiano Ronaldo   32
# 1           1           L. Messi   30
# 2           2             Neymar   25
# 3           3          L. Suárez   30
# 4           4           M. Neuer   31
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1  https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2  https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# 3  https://cdn.sofifa.org/48/18/players/176580.png     Uruguay
# 4  https://cdn.sofifa.org/48/18/players/167495.png     Germany
#
#                                   Flag  Overall  Potential  \
# ...

# %% [markdown]
# ## Competition History data

# %%
competition_history = pd.read_csv("data/results.csv")
competition_history.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False
